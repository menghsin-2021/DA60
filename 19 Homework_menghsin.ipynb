# %% [markdown]
# # 教學目標
#
# 主要說明matplotlib 的基礎操作
#
#
#
# # 範例重點
#
# 如何使用亂數, 資料集來操作

# %%
# %matplotlib notebook
# 載入需要的...
import matplotlib.pyplot as plt
import numpy as np

# 準備數據 ... 假設我要畫一個sin波 從0~180度
# 設定要畫的的x,y數據list....
x = np.arange(0,180)
y = np.cos(x * np.pi / 180.0)

# 開始畫圖
plt.plot(x,y)
# 在這個指令之前，都還在做畫圖的動作 
# 這個指令算是 "秀圖"
plt.show() 

#畫出完整的 sin 圖形
x = np.arange(0, 3 * np.pi, 0.1)
y_sin = np.sin(x)

plt.plot(x, y_sin)

plt.show()

#畫出完整的 cos 圖形

x = np.arange(0, 3 * np.pi, 0.1)
y_cos = np.cos(x)

plt.plot(x, y_cos)

plt.show()

	plt.savefig("filename.png",dpi=300,format="png")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # 散點圖: Scatter Plots
#
#     顏色由（X，Y）的角度給出。
#
#     注意標記的大小，顏色和透明度。

# %%
n = 1024
X = np.random.normal(0,1,n)
Y = np.random.normal(0,1,n)

plt.scatter(X, Y, color='b',alpha=0.5,s=100,edgecolors='red')
plt.title("Scatter plot ")

plt.xlim(-1.5,1.5)
plt.ylim(-1.5,1.5)

plt.show()

# %%
import itertools
n = 1024
X = np.random.normal(0,1,n)
Y = np.random.normal(0,1,n)

T = np.arctan2(Y,X)
plt.scatter(X,Y, s=75, c=T, alpha=.5)


plt.scatter(X, Y, c=T ,alpha=0.5,s=100,edgecolors='red')
plt.title("Scatter plot ")

plt.xlim(-1.5,1.5)
plt.ylim(-1.5,1.5)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# # labels = gmm.predict(Dist)
# #plot and save figure
# fig1 = plt.figure(1,figsize=(6,4))

# colors = ['b','g','r','orange']
# Label_Com = ['Component 1','Component 2','Component 3','Component 4']
# for index in range(4):
#     Price = data.loc[data['Label'] == index]['Price']
#     # Price = Dist[Labels[i] == index]
#     Index = data.loc[data['Label'] == index]['Number']
#     print("Done")
#     plt.scatter(Index, Price, c=colors[index], cmap='brg', s=40, alpha=0.2, marker='8', linewidth=0)  # ,cMAP

# plt.ylim(0.01,0.09)

# ax = fig1.gca()
# for label in ax.xaxis.get_ticklabels():
#     label.set_rotation(30)
# plt.xlabel('Time')
# plt.ylabel('Price')
# #added this to get the legend to work
# handles,labels = ax.get_legend_handles_labels()
# ax.legend(handles, labels = Label_Com, loc='upper right')
# Out:
# <img src="data:image/png;base64,..." width="600">
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-e0f5f6aac720> in <module>
#       6 Label_Com = ['Component 1','Component 2','Component 3','Component 4']
#       7 for index in range(4):
# ----> 8     Price = data.loc[data['Label'] == index]['Price']
#       9     # Price = Dist[Labels[i] == index]
#      10     Index = data.loc[data['Label'] == index]['Number']
#
# NameError: name 'data' is not defined
